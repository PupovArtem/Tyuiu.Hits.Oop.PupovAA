// %%
Flower rose = new Flower("Роза", "Цветок", 0.5f, "красный", 12);
rose.Bloom();
rose.Wither();

Console.WriteLine();

Tree willow = new Tree("Ива", "Дерево", 5.2f, 15, "узкие");
willow.Bloom();
willow.Ggrow(20);
public class Plant
{
    public string Name;
    public string Type;
    public float H;

    public Plant(string name, string type, float h)
    {
        Name = name;
        Type = type;
        H = h;
    }

    public virtual void Bloom()
    {
        Console.WriteLine($"{Name} цветёт...");
    }

    public virtual void Grow(double newGrow)
    {
        H = (float)newGrow;
    }
}

public class Flower : Plant
{
    public string Color;
    public int Quant;

    public Flower(string name, string type, float h, string color, int quant) : base(name, type, h)
    {
        Color = color;
        Quant = quant;
    }

    public override void Bloom()
    {
        base.Bloom();
        Console.WriteLine($"Цветок {Color} {Name} распускается и радует глаз!(Количество лепестков:{Quant})");
    }

    public void Wither()
    {
        base.Bloom();
        Console.WriteLine($"{Name} увядает..");
    }
}

public class Tree : Plant
{
    public int Age;
    public string LType;

    public Tree(string name, string type, float h, int age, string ltype) : base(name, type, h)
    {
        Age = age;
        LType = ltype;
    }

    public override void Bloom()
    {
        base.Bloom();
        Console.WriteLine($"Дерево {Name} покрывается новыми листьями(Тип листьев:{LType})");
    }

    public void Ggrow(int NewAge)
    {
        Age = NewAge;
        Console.WriteLine($"{Name} сейчас {NewAge} лет...");
    }
}
// Out:
// Роза цветёт...
// Цветок красный Роза распускается и радует глаз!(Количество лепестков:12)
// Роза цветёт...
// Роза увядает..
//
// Ива цветёт...
// Дерево Ива покрывается новыми листьями(Тип листьев:узкие)
// Ива сейчас 20 лет...
